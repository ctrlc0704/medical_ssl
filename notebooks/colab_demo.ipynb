# %%
# !git clone https://github.com/ctrlc0704/medical_ssl.git
# %cd medical_ssl

# !pip install timm torchvision scikit-learn

# Upload dataset vào /content/medical_ssl/data/

# !python pretrain_mae.py
# !python finetune.py
