# %%
# !git clone https://github.com/ctrlc0704/medical_ssl.git
# %cd medical_ssl
# !pip install -r requirements.txt

# !python train.py --config configs/kaggle.yaml --stage pretrain
# !python train.py --config configs/kaggle.yaml --stage finetune
